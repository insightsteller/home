# %% [markdown]
# # US Accidents Exploratory data analysis

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Import the CSV file

# %%
df=pd.read_csv('US_Accidents_Dec20_updated.csv')
df.head()

# %%
df.shape
# Out:
# (1516064, 47)

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516064 entries, 0 to 1516063
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1516064 non-null  object
#  1   Severity               1516064 non-null  int64
#  2   Start_Time             1516064 non-null  object
#  3   End_Time               1516064 non-null  object
#  4   Start_Lat              1516064 non-null  float64
#  5   Start_Lng              1516064 non-null  float64
#  6   End_Lat                1516064 non-null  float64
#  7   End_Lng                1516064 non-null  float64
#  8   Distance(mi)           1516064 non-null  float64
#  9   Description            1516064 non-null  object
#  10  Number                 469969 non-null   float64
#  11  Street                 1516064 non-null  object
#  12  Side                   1516064 non-null  object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  1.516064e+06  1.516064e+06  1.516064e+06  1.516064e+06  1.516064e+06
# mean   2.238630e+00  3.690056e+01 -9.859919e+01  3.690061e+01 -9.859901e+01
# std    6.081481e-01  5.165653e+00  1.849602e+01  5.165629e+00  1.849590e+01
# min    1.000000e+00  2.457022e+01 -1.244976e+02  2.457011e+01 -1.244978e+02
# 25%    2.000000e+00  3.385422e+01 -1.182076e+02  3.385420e+01 -1.182077e+02
# 50%    2.000000e+00  3.735113e+01 -9.438100e+01  3.735134e+01 -9.437987e+01
# 75%    2.000000e+00  4.072593e+01 -8.087469e+01  4.072593e+01 -8.087449e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  1.516064e+06  4.699690e+05    1.473031e+06   1.066748e+06
# mean   5.872617e-01  8.907533e+03    5.958460e+01   5.510976e+01
# std    1.632659e+00  2.242190e+04    1.827316e+01   2.112735e+01
# ...

# %% [markdown]
# ## Performing data preparation and data cleaning using pandas and numpy

# %%
# Conting Numeric columns in a dataset
numerics=['int16','int32','int64','float16','float32','float64']

numeric_df=df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %%
# Finding missing values in an dataset
df.isnull().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1046095
# Street                         0
# Side                           0
# City                          83
# County                         0
# State                          0
# Zipcode                      935
# Country                        0
# Timezone                    2302
# Airport_Code                4248
# Weather_Timestamp          30264
# Temperature(F)             43033
# Wind_Chill(F)             449316
# Humidity(%)                45509
# Pressure(in)               36274
# Visibility(mi)             44211
# Wind_Direction             41858
# Wind_Speed(mph)           128862
# ...

# %%
# Both isnull and isna function gives us the same output
df.isna().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1046095
# Street                         0
# Side                           0
# City                          83
# County                         0
# State                          0
# Zipcode                      935
# Country                        0
# Timezone                    2302
# Airport_Code                4248
# Weather_Timestamp          30264
# Temperature(F)             43033
# Wind_Chill(F)             449316
# Humidity(%)                45509
# Pressure(in)               36274
# Visibility(mi)             44211
# Wind_Direction             41858
# Wind_Speed(mph)           128862
# ...

# %% [markdown]
# ### Percentage if missing values per column

# %%
missing_percentage=df.isnull().sum().sort_values(ascending=False) /len(df) 
missing_percentage
# Out:
# Number                   0.690007
# Precipitation(in)        0.336760
# Wind_Chill(F)            0.296370
# Wind_Speed(mph)          0.084998
# Humidity(%)              0.030018
# Visibility(mi)           0.029162
# Weather_Condition        0.029027
# Temperature(F)           0.028385
# Wind_Direction           0.027610
# Pressure(in)             0.023926
# Weather_Timestamp        0.019962
# Airport_Code             0.002802
# Timezone                 0.001518
# Zipcode                  0.000617
# Sunrise_Sunset           0.000055
# Civil_Twilight           0.000055
# Nautical_Twilight        0.000055
# Astronomical_Twilight    0.000055
# City                     0.000055
# Country                  0.000000
# Give_Way                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Turning_Loop             0.000000
# Traffic_Signal           0.000000
# Traffic_Calming          0.000000
# ...

# %%
missing_percentage.plot()
# Out:
# <AxesSubplot:>

# %%
type(missing_percentage)
# Out:
# pandas.core.series.Series

# %%
missing_percentage.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# Filtering out zeros from the missing_percentage (pandas series)
missing_percentaege=missing_percentage[missing_percentage !=0].plot(kind='barh')

# %% [markdown]
# ### Remove columns tge you don't want to use

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# ## EDA And data visualization

# %% [markdown]
# ## Ask and Answer Questions
#
# #### Answeing by considering City and state
# 1. Are there more accidents in warmer or colder areas ?
# 2. which 5 states have the highest number of accidents ? How abount per capita ?
# 3. Does New York show up in the data ? If yes, why is the count lower if this the most populated city
# 4. Among the top 100 cities in number of accidents, which states do they belong to most frequently.
#
# #### Ansering by considering Time
# 5. What time of the day are acccidents most frequent in ?
# 6. which days of the week have the most accidents ?
# 7. Which month have the most accidents ?
# 8. What is the trend of accidents year over year (decreasing / increasing ?)
# 9. When is accidents per unit of traffic the highest .`

# %% [markdown]
# ## Visualization
#
# 1. City
# 2. Start time
# 3. Start lat and stat long
# 4. Temperature
# 5. Weather Condition
# 6. Sunrise_sunset
# 7. Civil_Twilight, Nautical_Twilight,
#        Astronomical_Twilight

# %% [markdown]
# ### City

# %%
cities=df.City.unique()
len(cities)
# Out:
# 10658

# %%
cities[:20]
# Out:
# array(['Dublin', 'Dayton', 'Cincinnati', 'Akron', 'Williamsburg',
#        'Batavia', 'Cleveland', 'Lima', 'Westerville', 'Jamestown',
#        'Freeport', 'Columbus', 'Toledo', 'Roanoke', 'Ft Mitchell',
#        'Edinburgh', 'Fairborn', 'Shelbyville', 'Greensburg', 'Saint Paul'],
#       dtype=object)

# %%
df['City'].describe()
# Out:
# count         1515981
# unique          10657
# top       Los Angeles
# freq            39984
# Name: City, dtype: object

# %%
cities_by_accident= df.City.value_counts()
cities_by_accident
# Out:
# Los Angeles                     39984
# Miami                           36233
# Charlotte                       22203
# Houston                         20843
# Dallas                          19497
#                                 ...
# Manzanita                           1
# West Brooklyn                       1
# Garfield Heights                    1
# Belding                             1
# American Fork-Pleasant Grove        1
# Name: City, Length: 10657, dtype: int64

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# Checking Does New York is present in the list or not
'New York' in cities
# New York is present in the cities but its very less data present in the dataset
# Out:
# True

# %%
# Which states have the cities with the most accidemts

# %%
sns.set_style('darkgrid')
sns.distplot(cities_by_accident)
# Out:
# C:\Users\gaura\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
high_accident_cities=cities_by_accident[cities_by_accident>=1000]
low_accident_cities=cities_by_accident[cities_by_accident<1000]

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.023550384687558643

# %%
sns.distplot(high_accident_cities)
# Out:
# C:\Users\gaura\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
sns.histplot(low_accident_cities,log_scale=True)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
cities_by_accident[cities_by_accident==1]
# Out:
# South Paris                     1
# Aberdeen Proving Ground         1
# Rebecca                         1
# Hiltons                         1
# Jeanerette                      1
#                                ..
# Manzanita                       1
# West Brooklyn                   1
# Garfield Heights                1
# Belding                         1
# American Fork-Pleasant Grove    1
# Name: City, Length: 1167, dtype: int64

# %% [markdown]
# ### Start Time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 00:37:08
# 1          2016-02-08 05:56:20
# 2          2016-02-08 06:15:39
# 3          2016-02-08 06:15:39
# 4          2016-02-08 06:51:45
#                   ...
# 1516059    2019-08-23 18:03:25
# 1516060    2019-08-23 19:11:30
# 1516061    2019-08-23 19:00:21
# 1516062    2019-08-23 19:00:21
# 1516063    2019-08-23 18:52:06
# Name: Start_Time, Length: 1516064, dtype: object

# %%
# Parseing dates using pandas
df['Start_Time']=pd.to_datetime(df.Start_Time)

# %%
# Accessing 2nd Index Line in a dataframe
df.Start_Time[2]
# Out:
# Timestamp('2016-02-08 06:15:39')

# %%
# Checking the Data type of Start_time Column
df.Start_Time.dtypes
# Out:
# dtype('<M8[ns]')

# %%
# Converting single value into hour 
df.Start_Time[0].hour
# Out:
# 0

# %%
df.Start_Time.dt.hour
# Out:
# 0           0
# 1           5
# 2           6
# 3           6
# 4           6
#            ..
# 1516059    18
# 1516060    19
# 1516061    19
# 1516062    19
# 1516063    18
# Name: Start_Time, Length: 1516064, dtype: int64

# %%
sns.histplot(df.Start_Time.dt.hour,bins=24)
# Out:
# <AxesSubplot:xlabel='Start_Time', ylabel='Count'>

# %%
sns.distplot(df.Start_Time.dt.hour,bins=24)
# Out:
# C:\Users\gaura\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time', ylabel='Density'>

# %%
sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False)
# Out:
# C:\Users\gaura\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# Convrting x axis values into percentage in seaborn
sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# C:\Users\gaura\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# ### A high percentage of accidents occur between 12pm to 5pm

# %%
# By looking the following graph we can conclude that there is less accidents on the weekends
sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# ### Is the distribution of accidents by hour the same on weekends as on weekdays.

# %%
sunday_Start_Time=df.Start_Time[df.Start_Time.dt.dayofweek ==6 ]
sns.distplot(sunday_Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# C:\Users\gaura\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# ### On sundays, the peak occurs between 12pm to 5pm unline week days

# %%
monday_Start_Time=df.Start_Time[df.Start_Time.dt.dayofweek ==0 ]
sns.distplot(monday_Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# # __________________________________________________________________________________________________________

# %%
sns.distplot(df.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# C:\Users\gaura\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# ## Can you explain the month wise treand of accidents ?

# %%
df.Start_Time.dt.year
# Out:
# 0          2016
# 1          2016
# 2          2016
# 3          2016
# 4          2016
#            ...
# 1516059    2019
# 1516060    2019
# 1516061    2019
# 1516062    2019
# 1516063    2019
# Name: Start_Time, Length: 1516064, dtype: int64

# %%
df_2019=df[df.Start_Time.dt.year==2016]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
df_2019=df[df.Start_Time.dt.year==2017]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
df_2019=df[df.Start_Time.dt.year==2018]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
df_2019=df[df.Start_Time.dt.year==2019]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %% [markdown]
# ### Start Latitude And Longitude

# %%
df.Start_Lat
# Out:
# 0          40.10891
# 1          39.86542
# 2          39.10266
# 3          39.10148
# 4          41.06213
#              ...
# 1516059    34.00248
# 1516060    32.76696
# 1516061    33.77545
# 1516062    33.99246
# 1516063    34.13393
# Name: Start_Lat, Length: 1516064, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -83.09286
# 1          -84.06280
# 2          -84.52468
# 3          -84.52341
# 4          -81.53784
#              ...
# 1516059   -117.37936
# 1516060   -117.14806
# 1516061   -117.84779
# 1516062   -118.40302
# 1516063   -117.23092
# Name: Start_Lng, Length: 1516064, dtype: float64

# %%
sns.scatterplot(x='Start_Lng',y='Start_Lat',data=df,size=0.1)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>

# %% [markdown]
# # Plot lat long on map in python

# %%
# import folium
# from folium.plugins import HeatMap

# %%
# lat ,lon=df.Start_Lat[0],df.Start_Lng[0]
# lat,lon
# # Comverting lat and lng into the list zip the each value of lat lng into the tuple using zip funciton
# list(zip(list(df.Start_Lng),list(df.Start_Lng)))

# %%
# map = folium.Map()

# folium.plugins.HeatMap(zip(list(df.Start_Lat),list(df.Start_Lng))).add_to(map)
# map

# %% [markdown]
# ## Summmary And Conclusion
#
# ### Insights
# - There is very little data of New York
# - The number of accident per city decreases exponentialy
# - Less than 1% of cities have more than 1000 yearly accidents
# - Over 1.1k+ cities reported only 1 accident ( Need to investigate )
# - Next Highest percentage of accidents is in between 6am to 9am
# - Much data is missing in year of 2016
